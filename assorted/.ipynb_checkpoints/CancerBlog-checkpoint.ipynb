# %% [markdown]
# # Predicting Cancer Mortality Rates
#
# ## Exploring Univariate and Multivariate Linear Regression to predict the number of cancer mortalities

# %% [markdown]
# ### Dataset variables and a brief description of each.
#
# The important takeaway of this section is to note that the TARGET_deathRate variable is what we're trying to *predict*, also known as the dependent variable - the outcome of this variable is dependent on other variables.
#
#
# **TARGET_deathRate**: *Dependent* variable. Mean per capita (100,000) cancer mortalities
#
# **avgAnnCount**: Mean number of reported cases of cancer diagnosed annually
#
# **avgDeathsPerYear**: Mean number of reported mortalities due to cancer
#
# **incidenceRate**: Mean per capita (100,000) cancer diagoses
#
# **medianIncome**: Median income per county
#
# **popEst2015**: Population of county
#
# **povertyPercent**: Percent of populace in poverty
#
# **studyPerCap**: Per capita number of cancer-related clinical trials per county
#
# **binnedInc**: Median income per capita binned by decile
#
# **MedianAge**: Median age of county residents
#
# **MedianAgeMale**: Median age of male county residents
#
# **MedianAgeFemale**: Median age of female county residents
#
# **Geography**: County name
#
# **AvgHouseholdSize**: Mean household size of county
#
# **PercentMarried**: Percent of county residents who are married
#
# **PctNoHS18_24**: Percent of county residents ages 18-24 highest education attained: less than high school
#
# **PctHS18_24**: Percent of county residents ages 18-24 highest education attained: high school diploma
#
# **PctSomeCol18_24**: Percent of county residents ages 18-24 highest education attained: some college
#
# **PctBachDeg18_24**: Percent of county residents ages 18-24 highest education attained: bachelor's degree
#
# **PctHS25_Over**: Percent of county residents ages 25 and over highest education attained: high school diploma
#
# **PctBachDeg25_Over**: Percent of county residents ages 25 and over highest education attained: bachelor's degree
#
# **PctEmployed16_Over**: Percent of county residents ages 16 and over employed
#
# **PctUnemployed16_Over**: Percent of county residents ages 16 and over unemployed
#
# **PctPrivateCoverage**: Percent of county residents with private health coverage
#
# **PctPrivateCoverageAlone**: Percent of county residents with private health coverage alone (no public assistance)
#
# **PctEmpPrivCoverage**: Percent of county residents with employee-provided private health coverage
#
# **PctPublicCoverage**: Percent of county residents with government-provided health coverage
#
# **PctPublicCoverageAlone**: Percent of county residents with government-provided health coverage alone
#
# **PctWhite**: Percent of county residents who identify as White
#
# **PctBlack**: Percent of county residents who identify as Black
#
# **PctAsian**: Percent of county residents who identify as Asian
#
# **PctOtherRace**: Percent of county residents who identify in a category which is not White, Black, or Asian
#
# **PctMarriedHouseholds**: Percent of married households
#
# **BirthRate**: Number of live births relative to number of women in county

# %% [markdown]
# -----------------------------------------------------------------------------------------------

# %% [markdown]
# ## Generalized Steps
#
# 1. Load & review data
# 2. Clean & transform
# 3. Find correlations for independent variable selection
# 4. Split model training and testing data
# 5. Train Univariate & Multivariate Linear Regression models
# 6. Review outputs and model accuracy

# %% [markdown]
# ## Library Selection
#
# **Pandas** - Used for dataframe generation, manipulation and general data exploration. Provides the bulk of the heavy lifting.
#
# **NumPy** - Numerical package that will mostly just be used for taking the square root for model performance.
#
# **Matplotlib** - Used for data visualizations for model results.
#
# **Seaborn** - Nice data visualization library basd on Matplotlib. Using mostly to provide a heatmap.
#
# **MissingNo** - Using for a nice visualize representation of missing values.
#
# **Pandas Profiler** - Library that creates a nice visal report about your data. Used here just for awareness purposes.
#
# **Sci-kit Learn** - Library that is providing our linear regression models. Also provides ease of train/test data splits.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno
from pandas_profiling import ProfileReport
from sklearn import linear_model
from sklearn import metrics
from sklearn.model_selection import train_test_split
pd.set_option("display.max.columns", None)

# %% [markdown]
# ### 1. Load & Review Data
#
# **As we can see, we're working with 3047 observations (rows) across 34 features (columns). We'll also review the first five observations to see what we're working with.**
#
# **Reviewing the data types, we can also see that some are listed as "object" still, which could indicate they hold data types we cannot use for our model (such as strings or categorical information)**

# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/fqz3z5pii3cpedbaevzfuixm3ju6gc', encoding='iso-8859-1')
df.shape
# Out:
# (3047, 34)

# %%
df.head()
# Out:
#    avgAnnCount  avgDeathsPerYear  TARGET_deathRate  incidenceRate  medIncome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popEst2015  povertyPercent  studyPerCap           binnedInc  MedianAge  \
# 0      260131            11.2   499.748204   (61494.5, 125635]       39.3
# 1       43269            18.6    23.111234  (48021.6, 51046.4]       33.0
# 2       21026            14.6    47.560164  (48021.6, 51046.4]       45.0
# 3       75882            17.1   342.637253    (42724.4, 45201]       42.8
# 4       10321            12.5     0.000000  (48021.6, 51046.4]       48.3
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3047 entries, 0 to 3046
# Data columns (total 34 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   avgAnnCount              3047 non-null   float64
#  1   avgDeathsPerYear         3047 non-null   int64
#  2   TARGET_deathRate         3047 non-null   float64
#  3   incidenceRate            3047 non-null   float64
#  4   medIncome                3047 non-null   int64
#  5   popEst2015               3047 non-null   int64
#  6   povertyPercent           3047 non-null   float64
#  7   studyPerCap              3047 non-null   float64
#  8   binnedInc                3047 non-null   object
#  9   MedianAge                3047 non-null   float64
#  10  MedianAgeMale            3047 non-null   float64
#  11  MedianAgeFemale          3047 non-null   float64
#  12  Geography                3047 non-null   object
#  13  AvgHouseholdSize         3047 non-null   float64
# ...

# %% [markdown]
# ### 2. Clean & Transform
#
# It'll be much easier working with this data in future sections if we convert our feature names to lowercase using the *map* function.

# %%
df.columns = map(str.lower, df.columns)

# %% [markdown]
# Using MissingNo to provide a graphical view of missing values. Gray represents present values, white represents missing values.
#
# As you can see, we're mostly concerned with three features - pctsomecol18_24, pctemployed16_over, pctprivatecoveragelone.

# %%
msno.matrix(df)

# %% [markdown]
# **We can also review missing values using the *isna* function. We can see we're dealing with 2,285, 152 and 609 missing values, respectively.**
#
# **This presents us with our first core decision point - what do we do with missing values? We have a few options:**
#
# 1. Do nothing
# 2. Imputation
# 3. Replace with zeros or some other constant
# 4. Drop the feature or observations with missing values
#
# **There are many pros/cons to each of these, and require a deeper understanding of the overall impact based on your decision. *This should not be taken lightly.***

# %%
df.isna().sum()
# Out:
# avganncount                   0
# avgdeathsperyear              0
# target_deathrate              0
# incidencerate                 0
# medincome                     0
# popest2015                    0
# povertypercent                0
# studypercap                   0
# binnedinc                     0
# medianage                     0
# medianagemale                 0
# medianagefemale               0
# geography                     0
# avghouseholdsize              0
# percentmarried                0
# pctnohs18_24                  0
# pcths18_24                    0
# pctsomecol18_24            2285
# pctbachdeg18_24               0
# pcths25_over                  0
# pctbachdeg25_over             0
# pctemployed16_over          152
# pctunemployed16_over          0
# pctprivatecoverage            0
# pctprivatecoveragealone     609
# pctempprivcoverage            0
# pctpubliccoverage             0
# pctpubliccoveragealone        0
# pctwhite                      0
# ...

# %% [markdown]
# **For the sake of fun and not necessarily "banking" on this output, we're going to impute the missing values using the mean of the feature.**
#
# **Lets first look at the columns with missing values and an example of their data. We can already see some NaN (Not a Number) values, which are returning missing values.**

# %%
old_colvalues = df[['pctsomecol18_24','pctemployed16_over','pctprivatecoveragealone']]
old_colvalues
# Out:
#       pctsomecol18_24  pctemployed16_over  pctprivatecoveragealone
# 0                42.1                51.9                      NaN
# 1                64.0                55.9                     53.8
# 2                 NaN                45.9                     43.5
# 3                36.1                48.3                     40.3
# 4                40.0                48.2                     43.9
# ...               ...                 ...                      ...
# 3042              NaN                51.7                     54.9
# 3043             35.6                70.1                     53.3
# 3044             33.3                64.8                     52.6
# 3045              NaN                 NaN                     56.3
# 3046             43.9                48.8                     60.3
#
# [3047 rows x 3 columns]

# %% [markdown]
# **Using basic imputation to fill missing values with the feature's mean.**

# %%
df.fillna(df.mean(),inplace=True)

# %% [markdown]
# **As we can see, we no longer have missing values.**

# %%
df.isna().sum()
# Out:
# avganncount                0
# avgdeathsperyear           0
# target_deathrate           0
# incidencerate              0
# medincome                  0
# popest2015                 0
# povertypercent             0
# studypercap                0
# binnedinc                  0
# medianage                  0
# medianagemale              0
# medianagefemale            0
# geography                  0
# avghouseholdsize           0
# percentmarried             0
# pctnohs18_24               0
# pcths18_24                 0
# pctsomecol18_24            0
# pctbachdeg18_24            0
# pcths25_over               0
# pctbachdeg25_over          0
# pctemployed16_over         0
# pctunemployed16_over       0
# pctprivatecoverage         0
# pctprivatecoveragealone    0
# pctempprivcoverage         0
# pctpubliccoverage          0
# pctpubliccoveragealone     0
# pctwhite                   0
# pctblack                   0
# pctasian                   0
# pctotherrace               0
# ...

# %% [markdown]
# **Quick review of the old column values in comparison to our new column values. Quick validation that the imputation worked.**

# %%
print(old_colvalues)
print('\n')
print(df[['pctsomecol18_24','pctemployed16_over','pctprivatecoveragealone']])
# Out:
#       pctsomecol18_24  pctemployed16_over  pctprivatecoveragealone
# 0                42.1                51.9                      NaN
# 1                64.0                55.9                     53.8
# 2                 NaN                45.9                     43.5
# 3                36.1                48.3                     40.3
# 4                40.0                48.2                     43.9
# ...               ...                 ...                      ...
# 3042              NaN                51.7                     54.9
# 3043             35.6                70.1                     53.3
# 3044             33.3                64.8                     52.6
# 3045              NaN                 NaN                     56.3
# 3046             43.9                48.8                     60.3
#
# [3047 rows x 3 columns]
#
#
#       pctsomecol18_24  pctemployed16_over  pctprivatecoveragealone
# 0           42.100000           51.900000                48.453774
# ...

# %% [markdown]
# **Re-reviewing the columns that are of type "object". Knowing the information in those features, we're going to drop these columns.**

# %%
df.dtypes == "object"
# Out:
# avganncount                False
# avgdeathsperyear           False
# target_deathrate           False
# incidencerate              False
# medincome                  False
# popest2015                 False
# povertypercent             False
# studypercap                False
# binnedinc                   True
# medianage                  False
# medianagemale              False
# medianagefemale            False
# geography                   True
# avghouseholdsize           False
# percentmarried             False
# pctnohs18_24               False
# pcths18_24                 False
# pctsomecol18_24            False
# pctbachdeg18_24            False
# pcths25_over               False
# pctbachdeg25_over          False
# pctemployed16_over         False
# pctunemployed16_over       False
# pctprivatecoverage         False
# pctprivatecoveragealone    False
# pctempprivcoverage         False
# pctpubliccoverage          False
# pctpubliccoveragealone     False
# ...

# %% [markdown]
# **Dropping the two object-type columns.**

# %%
df.drop(columns=['binnedinc','geography'], inplace=True)
df.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popest2015  povertypercent  studypercap  medianage  medianagemale  \
# 0      260131            11.2   499.748204       39.3           36.9
# 1       43269            18.6    23.111234       33.0           32.2
# 2       21026            14.6    47.560164       45.0           44.0
# 3       75882            17.1   342.637253       42.8           42.2
# 4       10321            12.5     0.000000       48.3           47.8
#
#    medianagefemale  avghouseholdsize  percentmarried  pctnohs18_24  \
# ...

# %% [markdown]
# ### 3. Find correlations for independent variable selection
#
# Now we want to look at correlations between our target feature (dependent variable) *target_deathrate* and other features (independent variables).
#
# Initial review shows us that our top three correlated variables are *incidencerate*, *pctpubliccoveragealone*, and *povertypercent*. As a quick reminder of what these mean:
#
# **incidenceRate**: Mean per capita (100,000) cancer diagoses
#
# **PctPublicCoverageAlone**: Percent of county residents with government-provided health coverage alone
#
# **povertyPercent**: Percent of populace in poverty
#
# In looking at these, we can feel a bit more confident that there is a correlation to cancer mortalities. Always remember, *correlation does not imply causation*.

# %%
corr = df.corr(method='pearson')
corr = corr.sort_values(by=['target_deathrate'],ascending=False)
corr
# Out:
#                          avganncount  avgdeathsperyear  target_deathrate  \
# target_deathrate           -0.143532         -0.090715          1.000000
# incidencerate               0.073553          0.062690          0.449432
# pctpubliccoveragealone     -0.093699         -0.027338          0.449358
# povertypercent             -0.135694         -0.066918          0.429389
# pcths25_over               -0.311375         -0.295929          0.404589
# pctpubliccoverage          -0.173548         -0.131687          0.404572
# pctunemployed16_over       -0.009016          0.069701          0.378412
# pcths18_24                 -0.182054         -0.151418          0.261976
# pctblack                    0.031376          0.084607          0.257024
# pctnohs18_24               -0.143327         -0.136794          0.088463
# medianagefemale            -0.122844         -0.144069          0.012048
# medianage                  -0.024098         -0.024599          0.004375
# ...

# %% [markdown]
# **Using Seaborn's heatmap to present a graphical correlation. This confirms what we've found earlier.**

# %%
plt.clf
fig, ax = plt.subplots(figsize=(20,15))  
sns.set(font_scale=1.5)
sns.heatmap(corr, ax=ax, linewidths=0.5, cmap='coolwarm')

# %% [markdown]
# **Reviewing the correlation coeffecients for the independent variables we're going to use.**

# %%
print('Cancer Diagnosis & Mortality Correlation = ', corr.loc['incidencerate', 'target_deathrate'])
print('Government Provided Insurance Alone & Mortality Correlation = ', corr.loc['pctpubliccoveragealone','target_deathrate'])
print('Poverty Percentage & Mortality Correlation = ', corr.loc['povertypercent', 'target_deathrate'])
# Out:
# Cancer Diagnosis & Mortality Correlation =  0.44943169756144524
# Government Provided Insurance Alone & Mortality Correlation =  0.4493575757853337
# Poverty Percentage & Mortality Correlation =  0.4293889802564514

# %% [markdown]
# ### 4. Split model training and testing data
#
# For the first effort we're going to be focusing on univariate linear regression, which means we have 1 independent variable and 1 dependent variable.
#
# For this we'll use the independent variable **povertypercent** and our typical target variable.

# %% [markdown]
# **Reshaping each variable to be the same shape**

# %%
X = df['povertypercent'].values.reshape(-1,1)
y = df['target_deathrate'].values.reshape(-1,1)

# %%
print(X[:10])
print('\n')
print(y[:10])
# Out:
# [[11.2]
#  [18.6]
#  [14.6]
#  [17.1]
#  [12.5]
#  [15.6]
#  [23.2]
#  [17.8]
#  [22.3]
#  [13.1]]
#
#
# [[164.9]
#  [161.3]
#  [174.7]
#  [194.8]
#  [144.4]
#  [176. ]
#  [175.9]
#  [183.6]
#  [190.5]
#  [177.8]]

# %% [markdown]
# **Using SKLearn's TrainTestSplit function to do a nice equal split of our model training and testing data.**

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X, y)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X1_train,y1_train)

# %%
model.score(X1_train,y1_train)
# Out:
# 0.1823918295788044

# %%
model.coef_
# Out:
# array([[1.88286216]])

# %%
model.intercept_
# Out:
# array([146.76596794])

# %%
print(X1_test.shape)
print(y1_test.shape)
# Out:
# (762, 1)
# (762, 1)

# %%
y1_pred = model.predict(X1_test)

# %%
output = pd.DataFrame({'Actual': y1_test.flatten(), 'Predicted': y1_pred.flatten()})
output['Error'] =  output['Actual'] - output['Predicted']
output
# Out:
#      Actual   Predicted      Error
# 0     158.9  183.481780 -24.581780
# 1     155.8  159.757717  -3.957717
# 2     158.4  154.297417   4.102583
# 3     165.3  183.481780 -18.181780
# 4     141.7  162.393724 -20.693724
# ..      ...         ...        ...
# 757   181.9  224.716461 -42.816461
# 758   163.7  158.251427   5.448573
# 759   203.8  192.896091  10.903909
# 760   137.4  175.950331 -38.550331
# 761   176.4  177.268335  -0.868335
#
# [762 rows x 3 columns]

# %%
colors = ['#787878','#00A658','#ad0707']
difplot = output.head(20)
difplot.plot(kind='bar',figsize=(16,10), color=colors)
plt.xlabel('Observation')
plt.ylabel('Mean Cancer Mortalities - Per 100k')
plt.show()

# %%
plt.scatter(X1_test,y1_test,edgecolors='k')
plt.plot(X1_test,y1_pred,color='red',linewidth=2)
plt.title('Mean Cancer Mortality Prediction per 100,000')
plt.ylabel('Cancer Mortality')
plt.xlabel('Poverty %')
plt.show()

# %%
r_square= model.score(X1_train, y1_train)
print('Coefficient of determination(R square):',r_square)
print('Mean Absolute Error:', metrics.mean_absolute_error(y1_test, y1_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y1_test,y1_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y1_test, y1_pred)))
# Out:
# Coefficient of determination(R square): 0.1823918295788044
# Mean Absolute Error: 18.453436607685656
# Mean Squared Error: 589.6210331757547
# Root Mean Squared Error: 24.28211344129161

# %% [markdown]
# ### Switching to Multivariate

# %%
df_mult = df.copy()
df_mult.head()
# Out:
#    avganncount  avgdeathsperyear  target_deathrate  incidencerate  medincome  \
# 0       1397.0               469             164.9          489.8      61898
# 1        173.0                70             161.3          411.6      48127
# 2        102.0                50             174.7          349.7      49348
# 3        427.0               202             194.8          430.4      44243
# 4         57.0                26             144.4          350.1      49955
#
#    popest2015  povertypercent  studypercap  medianage  medianagemale  \
# 0      260131            11.2   499.748204       39.3           36.9
# 1       43269            18.6    23.111234       33.0           32.2
# 2       21026            14.6    47.560164       45.0           44.0
# 3       75882            17.1   342.637253       42.8           42.2
# 4       10321            12.5     0.000000       48.3           47.8
#
#    medianagefemale  avghouseholdsize  percentmarried  pctnohs18_24  \
# ...

# %%
X = df_mult[['povertypercent','incidencerate','pctpubliccoveragealone']]
y = df_mult['target_deathrate']

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X, y)

# %%
lm = linear_model.LinearRegression()
mult_model = lm.fit(X2_train,y2_train)

# %%
y2_pred = mult_model.predict(X2_test)

# %%
mult_output = pd.DataFrame({'Actual': y2_test, 'Predicted': y2_pred.flatten()})
mult_output['Error'] =  mult_output['Actual'] - mult_output['Predicted']
mult_output.reset_index(drop=True,inplace=True)
mult_output
# Out:
#      Actual   Predicted      Error
# 0     176.0  191.045395 -15.045395
# 1     157.6  171.269469 -13.669469
# 2     136.9  153.859501 -16.959501
# 3     153.3  169.272088 -15.972088
# 4     108.8  145.731801 -36.931801
# ..      ...         ...        ...
# 757   169.9  169.704315   0.195685
# 758   154.8  171.586846 -16.786846
# 759   232.1  213.881888  18.218112
# 760   154.3  161.381269  -7.081269
# 761   131.6  151.032246 -19.432246
#
# [762 rows x 3 columns]

# %%
difplot = output.head(20)
difplot.plot(kind='bar',figsize=(16,10), color=colors)
plt.title('Univariate Analysis - Actuals, Predictions, Errors')
plt.xlabel('Observation')
plt.ylabel('Mean Cancer Mortalities - Per 100k')
plt.show()

difplot2 = mult_output.head(20)
difplot2.plot(kind='bar',figsize=(16,10), color=colors)
plt.title('Multivariate Analysis - Actuals, Predictions, Errors')
plt.xlabel('Observation')
plt.ylabel('Mean Cancer Mortalities - Per 100k')
plt.show()

# %%
print('Univariate Linear Regression Metrics:', '\n')
r_square= model.score(X1_train, y1_train)
print('Coefficient of determination(R square):',r_square)
print('Mean Absolute Error:', metrics.mean_absolute_error(y1_test, y1_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y1_test,y1_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y1_test, y1_pred)))
print('\n')

print('Multivariate Linear Regression Metrics:', '\n')
r_square= mult_model.score(X2_train, y2_train)
print('Coefficient of determination(R square):',r_square)
print('Mean Absolute Error:', metrics.mean_absolute_error(y2_test, y2_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y2_test, y2_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y2_test, y2_pred)))
# Out:
# Univariate Linear Regression Metrics:
#
# Coefficient of determination(R square): 0.1823918295788044
# Mean Absolute Error: 18.453436607685656
# Mean Squared Error: 589.6210331757547
# Root Mean Squared Error: 24.28211344129161
#
#
# Multivariate Linear Regression Metrics:
#
# Coefficient of determination(R square): 0.4033507683165347
# Mean Absolute Error: 16.273174740288283
# Mean Squared Error: 440.49334061677257
# Root Mean Squared Error: 20.987933214510964
